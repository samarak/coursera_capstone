# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
# ### Part 1: Scraping Postal Codes from Wikipidea

# %%
import requests # library to handle requests
import lxml.html as lh
import bs4 as bs
import urllib.request

import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

from geopy.geocoders import Nominatim
import folium

# %%
## Source URL
url   = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page  = urllib.request.urlopen(url).read()
soup  = bs.BeautifulSoup(page,'lxml')
table = soup.find("table",class_="wikitable")
header = [head.findAll(text=True)[0].strip() for head in table.find_all("th")]
data   = [[td.findAll(text=True)[0].strip() for td in tr.find_all("td")]for tr in table.find_all("tr")]
data= [row for row in data if len(row) == 3]
df = pd.DataFrame(data,columns=header)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.dropna(subset=['Borough'], inplace=True)

# %%
df= df.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df.columns = ['Postcode', 'Borough', 'Neighbourhood']

# %%
df['Neighbourhood'].replace('Not assigned', "Queen's Park", inplace=True)

# %%
df['Neighbourhood'].replace('Not assigned', "Queen's Park", inplace=True)

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## part 2

# %%
# !wget -O GeoCord.csv http://cocl.us/Geospatial_data/
# Out:
# --2019-03-06 22:14:09--  http://cocl.us/Geospatial_data/
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/ [following]
# --2019-03-06 22:14:09--  https://cocl.us/Geospatial_data/
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-03-06 22:14:11--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.26.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-03-06 22:14:12--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-03-06 22:14:12--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.25.211, 107.152.24.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.25.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!Url3_aPeov5lLapCyeQ6von2d0aEUBmInH1qHrcB_N8cDDSd_FNkrIqa3T5nkYjGBgAWrg52l6pvkTv4Ya9uQ1-Nck8gqilwe4YhfurcTApMESxWeTO3NKT3uJI-iCFq2H7_U9QCj6H37c-ybEF8Xhrb5cRO3O78wtQa7KrdLtqAaRjSw7DtSvuC4KFg1isZntmUAiM8V0uHa4iKo9qaCRBakXtg_EFCqK40ss2aj86L8DVyZpwJ6unPLpPEy-8Q-VeGyI3ZVlc3CATqPBP6OAqZGyhdQU0ai9iTb2GdvYisY_wFzJQGnOWbJOX6GRlWhHlAZrbAhT9zeOWFzk6n0cyrNqR51CS5zktWRuBOqYFgZDAWXl4zBb1jkCaHVCDHsR2ESxkjuU0twhV0SEChqulepW1akA3sdJuHQkytaSAFpYd0p3OqbUK_lS02brlw5NlCpWDkJcsUxB4R6wGiKo3CIOLwtzCypmafP3GF1EJvt92Y3Ra5gMQtkATHMvJ2KcHkfpkQo8FUkvO9XlvBMagtpDQvvYGNEieoUwDpcTQXfwA31Mph2cQG5ZTGsex2jeD8IeWQ2gxTSSkBOhqfm-FMER2TwjpjJYZ7NXXAz87VEhWWHF4nuLSCGbk68VWyn44N5HGsdHFyPVtoQfFA0U3hM-SpxXKDo3HgDDXr6br0u52u0VLQK
ORrHyIHI1mds24O0L7UxpuUj3wMlzqOcbl_nUM6D1OgQ1Iucvs1OpBG0gL74kscHIogANO9J3OxTOVpWcjDvKA0bVcylc9_rln04CZA_2TEyY0YNdHyWAwxRnQsCVBi9hFFZOA2AYnlOF2yrM6UGkU_3uGgYPO_DY3ZVhKp3fpdBqlr6Ze6AeJtayoscCB4vCC7ov2kFUeGA--4u8UD-g9kFE8gvGLwTGeNqrmSZ6z-KhgN2_Opp9illBiTVzaLuQjs--FxDTZV57UB3TTPpNfD_kFBv_TQZxi4Ab4-3JmGLRvmGsEAEYwKxUM3bBpx4FqYAezOmoAS6WX2h1rqjSwShef2NMSACeBvd74hzMcPMprpvCFk0sFl4n0kchAB6fKaAhCcVQETFZR5RzAgDDWi7dUF9MssvKeR-yXJ3OPHXRbwb-cjmxgoHjXJcUkU5al2zy0QEcdlYH3zarNdfJ5jtsnlLYmYOI6ioh3dbQx7mVfKV_kmM332dpP8mb9EldFCNZOQ3LSxJNbtdGBbT86EqQLEgCAt6hqqK92YNOzWXxn8NHdrRbSVMbwOGy-cyIOt/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘GeoCord.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-03-06 22:14:13 (506 MB/s) - ‘GeoCord.csv’ saved [2891/2891]

# %%
df_cord = pd.read_csv('GeoCord.csv') # Read the csv data
df_cord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Create Latitude and Longitude columns in df
df['Latitude'] = np.nan
df['Longitude'] = np.nan

# For each postcode in df, find corresponding coordinates in df_cord and assign it to df
for idx in df.index:
    cord_idx = df_cord['Postal Code'] == df.loc[idx, 'Postcode']
    df.at[idx, 'Latitude'] = df_cord.loc[cord_idx, 'Latitude'].values
    df.at[idx, 'Longitude'] = df_cord.loc[cord_idx, 'Longitude'].values
df.to_csv("df2.csv")
# Display the results
df.head(10)
# Out:
#   Postcode      Borough                                    Neighbourhood  \
# 0      M1B  Scarborough                                   Rouge, Malvern
# 1      M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough                Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                           Woburn
# 4      M1H  Scarborough                                        Cedarbrae
# 5      M1J  Scarborough                              Scarborough Village
# 6      M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7      M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8      M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9      M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476
# 5  43.744734 -79.239476
# 6  43.727929 -79.262029
# 7  43.711112 -79.284577
# 8  43.716316 -79.239476
# 9  43.692657 -79.264848

# %%
from geopy.geocoders import Nominatim
address = 'Toronto, Canada'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the City of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the City of Toronto are 43.653963, -79.387207.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
